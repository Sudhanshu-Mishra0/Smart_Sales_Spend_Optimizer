# %%
ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 8A4A-FEF4
#
#  Directory of e:\Ecosoul
#
# 01-10-2025  23:49    <DIR>          .
# 01-10-2025  23:50               600 main.ipynb
# 01-10-2025  23:07        73,212,026 orders_report-2024.xlsx
#                2 File(s)     73,212,626 bytes
#                1 Dir(s)  305,226,760,192 bytes free

# %%
import pandas as pd

# %%
data = pd.read_excel('orders_report-2024.xlsx')

# %%
data.head()
# Out:
#            Source.Name      amazon-order-id    merchant-order-id  \
# 0  orders_Apr-2024.txt  701-2542787-9089006  701-2542787-9089006
# 1  orders_Apr-2024.txt  701-5280482-3363430  701-5280482-3363430
# 2  orders_Apr-2024.txt  702-8141554-1226617  702-8141554-1226617
# 3  orders_Apr-2024.txt  702-7758644-4992244  702-7758644-4992244
# 4  orders_Apr-2024.txt  701-6214054-3109050  701-6214054-3109050
#
#         purchase-date   last-updated-date order-status fulfillment-channel  \
# 0 2024-04-12 18:45:07 2024-04-14 14:14:39      Shipped              Amazon
# 1 2024-04-10 02:50:22 2024-04-11 10:17:58      Shipped              Amazon
# 2 2024-04-10 01:55:21 2024-04-10 11:18:33      Shipped              Amazon
# 3 2024-04-09 21:06:28 2024-04-10 11:08:38      Shipped              Amazon
# 4 2024-04-09 06:38:04 2024-04-09 14:35:39      Shipped              Amazon
#
#    sales-channel order-channel  url  ... actual-ship-from-city  \
# ...

# %%
data.columns
# Out:
# Index(['Source.Name', 'amazon-order-id', 'merchant-order-id', 'purchase-date',
#        'last-updated-date', 'order-status', 'fulfillment-channel',
#        'sales-channel', 'order-channel', 'url', 'ship-service-level',
#        'product-name', 'sku', 'asin', 'number-of-items', 'item-status',
#        'tax-collection-model', 'tax-collection-responsible-party', 'quantity',
#        'currency', 'item-price', 'item-tax', 'shipping-price', 'shipping-tax',
#        'gift-wrap-price', 'gift-wrap-tax', 'item-promotion-discount',
#        'ship-promotion-discount', 'address-type', 'ship-city', 'ship-state',
#        'ship-postal-code', 'ship-country', 'promotion-ids',
#        'payment-method-details', 'item-extensions-data', 'is-business-order',
#        'purchase-order-number', 'price-designation', 'buyer-company-name',
#        'customized-url', 'customized-page', 'is-replacement-order',
#        'is-exchange-order', 'original-order-id', 'licensee-name',
# ...
